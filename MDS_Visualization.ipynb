# %%
import numpy as np
import matplotlib.pyplot as plt

class MyMDS:
    def __init__(self,d):
        self.d=d
    
    def fit(self,data,a):
        n,m = data.shape
        D = np.zeros((n,n))
        for i in range(n):
           for j in range(n):
               D[i][j] = np.power(np.linalg.norm(np.array(data[j]) - np.array(data[i])),a) 
        # genetrate the G
        D = np.asarray(D)
        DSquare = np.power(D, 2)
        totalMean = np.mean(DSquare)
        columnMean = np.mean(DSquare, axis = 0)
        rowMean = np.mean(DSquare, axis = 1)
        G = np.zeros(DSquare.shape)
        for i in range(G.shape[0]):
            for j in range(G.shape[1]):
                G[i][j] = -0.5 * (DSquare[i][j] - rowMean[i] - columnMean[j] + totalMean)
        # EVD of G
        eigVal, eigVec = np.linalg.eigh(G)
        #sort eigVal 
        sorted_idxes = np.argsort(-eigVal)
        #get d largest eigVec
        eigVal = eigVal[sorted_idxes]
        eigVec = eigVec[:,sorted_idxes]
        # dimension reduced
        eigVec = eigVec[:,0:self.d]
        eigVal = eigVal[0:self.d]
        # eigVal[eigVal < 0]=0 # if eigVal < 0 replace with 0
        eigVal = np.power(eigVal,0.5) 
        # get the result
        #X = np.dot(np.diag(eigVal),eigVec.T)
        X = np.real(eigVec * eigVal.T)
        return X

# %%
from sklearn.datasets import load_iris
from matplotlib.backends.backend_pdf import PdfPages
iris=load_iris()
 
clf1=MyMDS(2)
iris_t1=clf1.fit(iris.data,0.1)
plt.scatter(iris_t1[:,0],iris_t1[:,1],c=iris.target)
plt.title('iris_Using My MDS alpha=0.1')
# Out:
# Text(0.5, 1.0, 'iris_Using My MDS alpha=0.1')

# %%
from sklearn.datasets import load_iris
from matplotlib.backends.backend_pdf import PdfPages
iris=load_iris()
 
clf1=MyMDS(2)
iris_t1=clf1.fit(iris.data,0.01)
plt.scatter(iris_t1[:,0],iris_t1[:,1],c=iris.target)
plt.title('iris_Using My MDS alpha=0.01')
# Out:
# Text(0.5, 1.0, 'iris_Using My MDS alpha=0.01')

# %%
from sklearn.manifold import MDS
clf2=MDS(2)
clf2.fit(iris.data)
iris_t2=clf2.fit_transform(iris.data)
plt.scatter(iris_t2[:,0],iris_t2[:,1],c=iris.target)
plt.title('iris_Using sklearn MDS')
# Out:
# Text(0.5, 1.0, 'iris_Using sklearn MDS')

# %%
from sklearn.datasets import load_iris
iris=load_iris()
 
clf1=MyMDS(2)
iris_t1=clf1.fit(iris.data,0.2)
plt.scatter(iris_t1[:,0],iris_t1[:,1],c=iris.target)
plt.title('iris_Using My MDS alpha=0.2')
# Out:
# Text(0.5, 1.0, 'iris_Using My MDS alpha=0.2')

# %%
from sklearn.datasets import load_iris
iris=load_iris()
 
clf1=MyMDS(2)
iris_t1=clf1.fit(iris.data,0.6)
plt.scatter(iris_t1[:,0],iris_t1[:,1],c=iris.target)
plt.title('iris_Using My MDS alpha=0.6')
# Out:
# Text(0.5, 1.0, 'iris_Using My MDS alpha=0.6')

# %%
from sklearn.datasets import load_iris
iris=load_iris()
 
clf1=MyMDS(2)
iris_t1=clf1.fit(iris.data,1)
plt.scatter(iris_t1[:,0],iris_t1[:,1],c=iris.target)
plt.title('iris_Using My MDS alpha=1')
# Out:
# Text(0.5, 1.0, 'iris_Using My MDS alpha=1')

# %%
from sklearn.datasets import load_iris
iris=load_iris()
 
clf1=MyMDS(2)
iris_t1=clf1.fit(iris.data,3)
plt.scatter(iris_t1[:,0],iris_t1[:,1],c=iris.target)
plt.title('iris_Using My MDS alpha=3')
# Out:
# Text(0.5, 1.0, 'iris_Using My MDS alpha=3')

# %%
from sklearn.datasets import load_iris
iris=load_iris()
 
clf1=MyMDS(2)
iris_t1=clf1.fit(iris.data,20)
plt.scatter(iris_t1[:,0],iris_t1[:,1],c=iris.target)
plt.title('iris_Using My MDS alpha=20')
plt.xlim(-20*np.power(10,16), 20*np.power(10,16))
plt.ylim(-20*np.power(10,16), 20*np.power(10,16))
# Out:
# (-2e+17, 2e+17)

# %%
# additional datasets-digits
from sklearn.datasets import load_digits
digits=load_digits()
clf3=MyMDS(2)
digits_t1=clf3.fit(digits.data,0.01)
plt.scatter(digits_t1[:,0],digits_t1[:,1],c=digits.target)
plt.colorbar()
plt.title('digits_Using My MDS alpha=0.01')
# Out:
# Text(0.5, 1.0, 'digits_Using My MDS alpha=0.01')

# %%
# additional datasets-digits
from sklearn.datasets import load_digits
digits=load_digits()
clf3=MyMDS(2)
digits_t1=clf3.fit(digits.data,0.1)
plt.scatter(digits_t1[:,0],digits_t1[:,1],c=digits.target)
plt.colorbar()
plt.title('digits_Using My MDS alpha=0.1')
# Out:
# Text(0.5, 1.0, 'digits_Using My MDS alpha=0.1')

# %%
# additional datasets-digits
from sklearn.datasets import load_digits
digits=load_digits()

clf3=MyMDS(2)
digits_t1=clf3.fit(digits.data,0.5)
plt.scatter(digits_t1[:,0],digits_t1[:,1],c=digits.target)
plt.colorbar()
plt.title('digits_Using My MDS alpha=0.5')
# Out:
# Text(0.5, 1.0, 'Using My MDS alpha=0.5')

# %%
# additional datasets-digits
from sklearn.datasets import load_digits
digits=load_digits()

clf3=MyMDS(2)
digits_t1=clf3.fit(digits.data,1)
plt.scatter(digits_t1[:,0],digits_t1[:,1],c=digits.target)
plt.colorbar()
plt.title('digits_Using My MDS alpha=1')
# Out:
# Text(0.5, 1.0, 'digits_Using My MDS alpha=1')

# %%
# additional datasets-digits
from sklearn.datasets import load_digits
digits=load_digits()
clf3=MyMDS(2)
digits_t1=clf3.fit(digits.data,6)
plt.scatter(digits_t1[:,0],digits_t1[:,1],c=digits.target)
plt.colorbar()
plt.title('digits_Using My MDS alpha=6')
# Out:
# Text(0.5, 1.0, 'digits_Using My MDS alpha=6')

# %%
# additional datasets-digits
from sklearn.datasets import load_digits
digits=load_digits()
clf3=MyMDS(2)
digits_t1=clf3.fit(digits.data,20)
plt.scatter(digits_t1[:,0],digits_t1[:,1],c=digits.target)
plt.colorbar()
plt.title('digits_Using My MDS alpha=20')
# Out:
# Text(0.5, 1.0, 'digits_Using My MDS alpha=20')

# %%
# additional datasets-wine
from sklearn.datasets import load_wine
wines=load_wine()
clf4=MyMDS(2)
wines_t1=clf4.fit(wines.data,0.01)
plt.scatter(wines_t1[:,0],wines_t1[:,1],c=wines.target)
plt.colorbar()
plt.title('wines_Using My MDS alpha=0.01')
# Out:
# Text(0.5, 1.0, 'wines_Using My MDS alpha=0.01')

# %%
# additional datasets-wine
from sklearn.datasets import load_wine
wines=load_wine()
clf4=MyMDS(2)
wines_t1=clf4.fit(wines.data,1)
plt.scatter(wines_t1[:,0],wines_t1[:,1],c=wines.target)
plt.colorbar()
plt.title('wines_Using My MDS alpha=1')
# Out:
# Text(0.5, 1.0, 'wines_Using My MDS alpha=1')

# %%
# additional datasets-wine
from sklearn.datasets import load_wine
wines=load_wine()
clf4=MyMDS(2)
wines_t1=clf4.fit(wines.data,0.1)
plt.scatter(wines_t1[:,0],wines_t1[:,1],c=wines.target)
plt.colorbar()
plt.title('wines_Using My MDS alpha=0.1')
# Out:
# Text(0.5, 1.0, 'wines_Using My MDS alpha=0.1')

# %%
# additional datasets-wine
from sklearn.datasets import load_wine
wines=load_wine()
clf4=MyMDS(2)
wines_t1=clf4.fit(wines.data,0.5)
plt.scatter(wines_t1[:,0],wines_t1[:,1],c=wines.target)
plt.colorbar()
plt.title('wines_Using My MDS alpha=0.5')
# Out:
# Text(0.5, 1.0, 'wines_Using My MDS alpha=0.5')

# %%
# additional datasets-wine
from sklearn.datasets import load_wine
wines=load_wine()
clf4=MyMDS(2)
wines_t1=clf4.fit(wines.data,6)
plt.scatter(wines_t1[:,0],wines_t1[:,1],c=wines.target)
plt.colorbar()
plt.title('wines_Using My MDS alpha=6')
# Out:
# Text(0.5, 1.0, 'wines_Using My MDS alpha=6')

# %%
# additional datasets-wine
from sklearn.datasets import load_wine
wines=load_wine()
clf4=MyMDS(2)
wines_t1=clf4.fit(wines.data,20)
plt.scatter(wines_t1[:,0],wines_t1[:,1],c=wines.target)
plt.colorbar()
plt.title('wines_Using My MDS alpha=20')
# Out:
# Text(0.5, 1.0, 'wines_Using My MDS alpha=20')

# %%
from sklearn.datasets import fetch_olivetti_faces
faces=fetch_olivetti_faces()
clf5=MyMDS(2)
faces_t1=clf4.fit(faces.data,1)
plt.scatter(faces_t1[:,0],faces_t1[:,1],c=faces.target)
plt.colorbar()
plt.title('wines_Using My MDS alpha=1')
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /Users/gy/scikit_learn_data
# Text(0.5, 1.0, 'wines_Using My MDS alpha=1')
